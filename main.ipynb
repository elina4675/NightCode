# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    for block in message.content:
        if block.type == "text":
            return block.text

# %%
messages = []

while True:
    user_input = input("> ")
    print("> ", user_input)
    add_user_message(messages, user_input)

    with client.messages.stream(
            model=model, 
            max_tokens=1000,
            messages=messages,
    ) as stream:
        for text in stream.text_stream:
            print(text, end="")
            pass
    
    stream.get_final_message()
# Out:
# >  hellooo!
# Hey there! 👋 How's it going? What's up?>  tell me more about databases
# # Hey! 👋
#
# Happy to dive into databases! Here's a quick overview:
#
# ## What's a Database?
# A structured collection of data stored and organized so it's easy to access, manage, and update.
#
# ## Main Types
#
# **Relational (SQL)**
# - Data organized in tables (rows & columns)
# - Examples: PostgreSQL, MySQL, SQL Server
# - Great for structured data with clear relationships
# - Uses SQL queries
#
# **NoSQL**
# - Non-tabular formats: documents, key-value pairs, graphs, etc.
# - Examples: MongoDB, Redis, Cassandra
# - More flexible structure, scales well horizontally
# - Good for unstructured/semi-structured data
#
# ## Key Concepts
# - **ACID** - Reliability (Atomicity, Consistency, Isolation, Durability)
# - **Indexes** - Speed up queries
# - **Joins** - Combine data from multiple tables
# - **Transactions** - Groups of operations that succeed/fail together
#
# ## When to Use What
# - **SQL**: Financial systems, CRM, business apps (need accuracy & relationships)
# - **NoSQL**: Real-time analytics, user profiles, content management (need flexibility & speed)
#
# ---
#
# **What aspect interests you most?**
# - Database design?
# - A specific type?
# - How to query them?
# - Performance/scaling?>
# # Hey! 👋 Great question!
#
# ## What are Databases?
#
# Databases are organized systems for
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 13
#       9             model=model,
#      10             max_tokens=1000,
#      11             messages=messages,
#      12     ) as stream:
# ---> 13         for text in stream.text_stream:
#      14             print(text, end="")
#      15             pass
#      16
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/lib/streaming/_messages.py:145, in MessageStream.__stream_text__(self)
#     144 def __stream_text__(self) -> Iterator[str]:
# --> 145     for chunk in self:
#     146         if chunk.type == "content_block_delta" and chunk.delta.type == "text_delta":
#     147             yield chunk.delta.text
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/lib/streaming/_messages.py:71, in MessageStream.__iter__(self)
#      70 def __iter__(self) -> Iterator[ParsedMessageStreamEvent[ResponseFormatT]]:
# ---> 71     for item in self._iterator:
#      72         yield item
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/lib/streaming/_messages.py:133, in MessageStream.__stream__(self)
#     132 def __stream__(self) -> Iterator[ParsedMessageStreamEvent[ResponseFormatT]]:
# --> 133     for sse_event in self._raw_stream:
#     134         self.__final_message_snapshot = accumulate_event(
#     135             event=sse_event,
#     136             current_snapshot=self.__final_message_snapshot,
#     137             output_format=self.__output_format,
#     138         )
#     140         events_to_fire = build_events(event=sse_event, message_snapshot=self.current_message_snapshot)
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/_streaming.py:71, in Stream.__iter__(self)
#      70 def __iter__(self) -> Iterator[_T]:
# ---> 71     for item in self._iterator:
#      72         yield item
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/_streaming.py:93, in Stream.__stream__(self)
#      90 iterator = self._iter_events()
#      92 try:
# ---> 93     for sse in iterator:
#      94         if sse.event == "completion":
#      95             yield process_data(data=sse.json(), cast_to=cast_to, response=response)
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/_streaming.py:75, in Stream._iter_events(self)
#      74 def _iter_events(self) -> Iterator[ServerSentEvent]:
# ---> 75     yield from self._decoder.iter_bytes(self.response.iter_bytes())
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/_streaming.py:429, in SSEDecoder.iter_bytes(self, iterator)
#     427 def iter_bytes(self, iterator: Iterator[bytes]) -> Iterator[ServerSentEvent]:
#     428     """Given an iterator that yields raw binary data, iterate over it & yield every event encountered"""
# --> 429     for chunk in self._iter_chunks(iterator):
#     430         # Split before decoding so splitlines() only uses \r and \n
#     431         for raw_line in chunk.splitlines():
#     432             line = raw_line.decode("utf-8")
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/anthropic/_streaming.py:440, in SSEDecoder._iter_chunks(self, iterator)
#     438 """Given an iterator that yields raw binary data, iterate over it and yield individual SSE chunks"""
#     439 data = b""
# --> 440 for chunk in iterator:
#     441     for line in chunk.splitlines(keepends=True):
#     442         data += line
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Downloads/API course/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
#messages = []
#add_user_message(messages, "Write 1 sentence description of a fake database")

#with client.messages.stream(
#        model=model, 
#        max_tokens=1000,
#        messages=messages,
#) as stream:
#    for text in stream.text_stream:
#        print(text, end="")
#        pass
    
#stream.get_final_message()

# %%
#messages = []
#prompt = """
#Generate three different sample AWS CLI commands. #Each should be very short.
#"""
#add_user_message(messages, prompt)
#add_assistant_message(messages, "Here are all tree #commands in single block without any #comments:\n```bash")

#text = chat(messages, stop_sequences=["```"])
#print(text.strip())
# Out:
# aws s3 ls
# aws ec2 describe-instances
# aws dynamodb list-tables
