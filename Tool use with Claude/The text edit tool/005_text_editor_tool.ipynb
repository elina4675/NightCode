# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit.

    Then create a ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and then write tests for it.
#
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula or a more efficient method like the Machin formula for better convergence.
# Now let's create the test file:
# Perfect! Let me verify the files were created correctly:
#
# Perfect! I've successfully created both files. Here's what I've done:
#
# ## **main.py**
# Added a `calculate_pi()` function that:
# - Calculates pi to the 5th decimal digit (default) using **Machin's formula**: π/4 = 4×arctan(1/5) - arctan(1/239)
# - Uses Taylor series expansion to compute arctangent values
# - Returns **3.14159** when called with 5 digits
# - Accepts a `digits` parameter to allow different precision levels
#
# The Machin formula is more efficient than simple methods like the Leibniz formula and converges much faster to accurate values.
#
# ## **test.py**
# Created comprehensive unit tests including:
# 1. **test_pi_5_digits** - Verifies the result is exactly 3.14159
# 2. **test_pi_accuracy** - Compares against Python's math.pi
# 3. **test_pi_3_digits** - Tests with 3 decimal places
# 4. **test_pi_2_digits** - Tests with 2 decimal places
# 5. **test_pi_default_parameter** - Ensures default behavior works
# 6. **test_pi_first_digit** - Validates the integer part is 3
# 7. **test_pi_return_type** - Checks return type is float
#
# The test file also includes a `run_tests()` function that provides a nice summary of test results and shows the calculated value compared to the actual value of pi.
#
# You can run the tests by executing:
# ```bash
# python test.py
# ```
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n\n    Then create a ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and then write tests for it.", type='text'),
#    ToolUseBlock(id='toolu_011KPoss7D73ERsBaSo5FwmF', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_011KPoss7D73ERsBaSo5FwmF',
#     'content': '".backups\\nmain.py\\n005_text_editor_tool.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01VQRFjsWS9qoN2RLbjKqgfm', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01VQRFjsWS9qoN2RLbjKqgfm',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula or a more efficient method like the Machin formula for better convergence.", type='text'),
#    ToolUseBlock(id='toolu_01DsVmTWaujNJFkuVEDqrZA6', caller=DirectCaller(type='direct'), input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("Hi there")', 'new_str': 'def greeting():\n    print("Hi there")\n\n\ndef calculate_pi(digits=5):\n    """\n    Calculate pi to the specified number of digits using the Machin formula.\n    Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    \n    Args:\n        digits: Number of decimal digits to calculate (default: 5)\n    \n    Returns:\n        float: Value of pi accurate to the specified digits\n    """\n    def arctan(x, num_terms):\n        """Calculate arctan using Taylor series expansion"""\n        result = 0\n        x_squared = x * x\n        x_power = x\n        for n in range(num_terms):\n            sign = (-1) ** n\n            result += sign * x_power / (2 * n + 1)\n            x_power *= x_squared\n        return result\n    \n    # Using more terms for better accuracy\n    # For 5 decimal places, we need about 500 terms\n    num_terms = 500\n    \n    # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    pi_over_4 = 4 * arctan(1/5, num_terms) - arctan(1/239, num_terms)\n    pi_value = 4 * pi_over_4\n    \n    # Round to the specified number of digits\n    return round(pi_value, digits)'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01DsVmTWaujNJFkuVEDqrZA6',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create the test file:", type='text'),
#    ToolUseBlock(id='toolu_01EL9QrnT8B5AqvG9Ts9mYvK', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nimport math\nfrom main import calculate_pi\n\n\nclass TestPiCalculation(unittest.TestCase):\n    """Test cases for the calculate_pi function"""\n    \n    def test_pi_5_digits(self):\n        """Test pi calculation to 5 decimal places"""\n        result = calculate_pi(5)\n        expected = 3.14159\n        self.assertEqual(result, expected, \n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_accuracy(self):\n        """Test that calculated pi is close to math.pi"""\n        result = calculate_pi(5)\n        # Check that the result is within acceptable range\n        self.assertAlmostEqual(result, math.pi, places=5,\n                              msg=f"Calculated pi {result} not accurate enough")\n    \n    def test_pi_3_digits(self):\n        """Test pi calculation to 3 decimal places"""\n        result = calculate_pi(3)\n        expected = 3.142\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_2_digits(self):\n        """Test pi calculation to 2 decimal places"""\n        result = calculate_pi(2)\n        expected = 3.14\n        self.assertEqual(result, expected,\n                        f"Expected {expected}, but got {result}")\n    \n    def test_pi_default_parameter(self):\n        """Test that default parameter gives 5 digits"""\n        result = calculate_pi()\n        expected = 3.14159\n        self.assertEqual(result, expected,\n                        f"Expected {expected} with default parameter, but got {result}")\n    \n    def test_pi_first_digit(self):\n        """Test that the integer part of pi is correct"""\n        result = calculate_pi(5)\n        self.assertEqual(int(result), 3,\n                        "The integer part of pi should be 3")\n    \n    def test_pi_return_type(self):\n        """Test that the function returns a float"""\n        result = calculate_pi(5)\n        self.assertIsInstance(result, float,\n                            f"Expected float, but got {type(result)}")\n\n\ndef run_tests():\n    """Run all tests and print results"""\n    # Create a test suite\n    suite = unittest.TestLoader().loadTestsFromTestCase(TestPiCalculation)\n    \n    # Run the tests with verbose output\n    runner = unittest.TextTestRunner(verbosity=2)\n    result = runner.run(suite)\n    \n    # Print summary\n    print("\\n" + "="*70)\n    print(f"Tests run: {result.testsRun}")\n    print(f"Successes: {result.testsRun - len(result.failures) - len(result.errors)}")\n    print(f"Failures: {len(result.failures)}")\n    print(f"Errors: {len(result.errors)}")\n    print("="*70)\n    \n    # Print actual calculated value\n    print(f"\\nCalculated Pi (5 digits): {calculate_pi(5)}")\n    print(f"Actual Pi (math.pi):      {round(math.pi, 5)}")\n    print(f"Difference:               {abs(calculate_pi(5) - round(math.pi, 5))}")\n\n\nif __name__ == "__main__":\n    run_tests()\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01EL9QrnT8B5AqvG9Ts9mYvK',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me verify the files were created correctly:', type='text'),
#    ToolUseBlock(id='toolu_01XLVQRya1gHBx7Fs2tfcZhq', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01XLVQRya1gHBx7Fs2tfcZhq',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to the specified number of digits using the Machin formula.\\n8:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n9:     \\n10:     Args:\\n11:         digits: Number of decimal digits to calculate (default: 5)\\n12:     \\n13:     Returns:\\n14:         float: Value of pi accurate to the specified digits\\n15:     \\"\\"\\"\\n16:     def arctan(x, num_terms):\\n17:         \\"\\"\\"Calculate arctan using Taylor series expansion\\"\\"\\"\\n18:         result = 0\\n19:         x_squared = x * x\\n20:         x_power = x\\n21:         for n in range(num_terms):\\n22:             sign = (-1) ** n\\n23:             result += sign * x_power / (2 * n + 1)\\n24:             x_power *= x_squared\\n25:         return result\\n26:     \\n27:     # Using more terms for better accuracy\\n28:     # For 5 decimal places, we need about 500 terms\\n29:     num_terms = 500\\n30:     \\n31:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n32:     pi_over_4 = 4 * arctan(1/5, num_terms) - arctan(1/239, num_terms)\\n33:     pi_value = 4 * pi_over_4\\n34:     \\n35:     # Round to the specified number of digits\\n36:     return round(pi_value, digits)"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01HRwpFA4CmHsYpL2XhgwTH3', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01HRwpFA4CmHsYpL2XhgwTH3',
#     'content': '"1: import unittest\\n2: import math\\n3: from main import calculate_pi\\n4: \\n5: \\n6: class TestPiCalculation(unittest.TestCase):\\n7:     \\"\\"\\"Test cases for the calculate_pi function\\"\\"\\"\\n8:     \\n9:     def test_pi_5_digits(self):\\n10:         \\"\\"\\"Test pi calculation to 5 decimal places\\"\\"\\"\\n11:         result = calculate_pi(5)\\n12:         expected = 3.14159\\n13:         self.assertEqual(result, expected, \\n14:                         f\\"Expected {expected}, but got {result}\\")\\n15:     \\n16:     def test_pi_accuracy(self):\\n17:         \\"\\"\\"Test that calculated pi is close to math.pi\\"\\"\\"\\n18:         result = calculate_pi(5)\\n19:         # Check that the result is within acceptable range\\n20:         self.assertAlmostEqual(result, math.pi, places=5,\\n21:                               msg=f\\"Calculated pi {result} not accurate enough\\")\\n22:     \\n23:     def test_pi_3_digits(self):\\n24:         \\"\\"\\"Test pi calculation to 3 decimal places\\"\\"\\"\\n25:         result = calculate_pi(3)\\n26:         expected = 3.142\\n27:         self.assertEqual(result, expected,\\n28:                         f\\"Expected {expected}, but got {result}\\")\\n29:     \\n30:     def test_pi_2_digits(self):\\n31:         \\"\\"\\"Test pi calculation to 2 decimal places\\"\\"\\"\\n32:         result = calculate_pi(2)\\n33:         expected = 3.14\\n34:         self.assertEqual(result, expected,\\n35:                         f\\"Expected {expected}, but got {result}\\")\\n36:     \\n37:     def test_pi_default_parameter(self):\\n38:         \\"\\"\\"Test that default parameter gives 5 digits\\"\\"\\"\\n39:         result = calculate_pi()\\n40:         expected = 3.14159\\n41:         self.assertEqual(result, expected,\\n42:                         f\\"Expected {expected} with default parameter, but got {result}\\")\\n43:     \\n44:     def test_pi_first_digit(self):\\n45:         \\"\\"\\"Test that the integer part of pi is correct\\"\\"\\"\\n46:         result = calculate_pi(5)\\n47:         self.assertEqual(int(result), 3,\\n48:                         \\"The integer part of pi should be 3\\")\\n49:     \\n50:     def test_pi_return_type(self):\\n51:         \\"\\"\\"Test that the function returns a float\\"\\"\\"\\n52:         result = calculate_pi(5)\\n53:         self.assertIsInstance(result, float,\\n54:                             f\\"Expected float, but got {type(result)}\\")\\n55: \\n56: \\n57: def run_tests():\\n58:     \\"\\"\\"Run all tests and print results\\"\\"\\"\\n59:     # Create a test suite\\n60:     suite = unittest.TestLoader().loadTestsFromTestCase(TestPiCalculation)\\n61:     \\n62:     # Run the tests with verbose output\\n63:     runner = unittest.TextTestRunner(verbosity=2)\\n64:     result = runner.run(suite)\\n65:     \\n66:     # Print summary\\n67:     print(\\"\\\\n\\" + \\"=\\"*70)\\n68:     print(f\\"Tests run: {result.testsRun}\\")\\n69:     print(f\\"Successes: {result.testsRun - len(result.failures) - len(result.errors)}\\")\\n70:     print(f\\"Failures: {len(result.failures)}\\")\\n71:     print(f\\"Errors: {len(result.errors)}\\")\\n72:     print(\\"=\\"*70)\\n73:     \\n74:     # Print actual calculated value\\n75:     print(f\\"\\\\nCalculated Pi (5 digits): {calculate_pi(5)}\\")\\n76:     print(f\\"Actual Pi (math.pi):      {round(math.pi, 5)}\\")\\n77:     print(f\\"Difference:               {abs(calculate_pi(5) - round(math.pi, 5))}\\")\\n78: \\n79: \\n80: if __name__ == \\"__main__\\":\\n81:     run_tests()\\n82: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've successfully created both files. Here's what I've done:\n\n## **main.py**\nAdded a `calculate_pi()` function that:\n- Calculates pi to the 5th decimal digit (default) using **Machin's formula**: π/4 = 4×arctan(1/5) - arctan(1/239)\n- Uses Taylor series expansion to compute arctangent values\n- Returns **3.14159** when called with 5 digits\n- Accepts a `digits` parameter to allow different precision levels\n\nThe Machin formula is more efficient than simple methods like the Leibniz formula and converges much faster to accurate values.\n\n## **test.py**\nCreated comprehensive unit tests including:\n1. **test_pi_5_digits** - Verifies the result is exactly 3.14159\n2. **test_pi_accuracy** - Compares against Python's math.pi\n3. **test_pi_3_digits** - Tests with 3 decimal places\n4. **test_pi_2_digits** - Tests with 2 decimal places\n5. **test_pi_default_parameter** - Ensures default behavior works\n6. **test_pi_first_digit** - Validates the integer part is 3\n7. **test_pi_return_type** - Checks return type is float\n\nThe test file also includes a `run_tests()` function that provides a nice summary of test results and shows the calculated value compared to the actual value of pi.\n\nYou can run the tests by executing:\n```bash\npython test.py\n```", type='text')]}]
